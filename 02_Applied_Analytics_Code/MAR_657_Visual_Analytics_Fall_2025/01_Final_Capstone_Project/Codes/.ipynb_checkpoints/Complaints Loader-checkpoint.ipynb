# %%
import pandas as pd

# %%
# Load the CSV file
complaints = pd.read_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Raw data/Complaints/NYPD_Complaint_Data_Current_YTD_20251114.csv')

# %%
print('Columns:', complaints.columns)
# Out:
# Columns: Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon', 'New Georeferenced Column'],
#       dtype='object')

# %%
print('Data shape:', complaints.shape)
# Out:
# Data shape: (438556, 36)

# %%
print(complaints.head(20))
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD        BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 0   303250435           13      MANHATTAN   03/20/2025     00:30:00
# 1   298788022           81       BROOKLYN   01/02/2025     01:50:00
# 2   307271594           47          BRONX   03/05/2025     17:00:00
# 3   306868358            9      MANHATTAN   05/22/2025     14:30:00
# 4   309137838           14      MANHATTAN   07/05/2025     18:00:00
# 5   312320890           46          BRONX   09/03/2025     22:06:00
# 6   304027469          116         QUEENS   04/01/2025     08:30:00
# 7   311083105           34      MANHATTAN   08/12/2025     12:30:00
# 8   313240502          121  STATEN ISLAND   09/17/2025     18:00:00
# 9   304170874          120  STATEN ISLAND   04/03/2025     15:32:00
# 10  313088262          123  STATEN ISLAND   09/16/2025     16:00:00
# 11  304263404          123  STATEN ISLAND   04/05/2025     04:45:00
# 12  309359259          123  STATEN ISLAND   07/09/2025     23:20:00
# 13  310939996          122  STATEN ISLAND   08/09/2025     08:45:00
# 14  309900537          121  STATEN ISLAND   07/19/2025     17:40:00
# 15  311636497          121  STATEN ISLAND   08/22/2025     15:16:00
# 16  302223944          121  STATEN ISLAND   01/23/2025     15:50:00
# 17  300186281          121  STATEN ISLAND   01/26/2025     01:00:00
# 18  299558420          122  STATEN ISLAND   12/13/2024     11:30:00
# 19  309052210          123  STATEN ISLAND   07/02/2025     19:00:00
#
#    CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  \
# 0           NaN       (null)        COMPLETED     (null)          NaN  ...
# 1    01/02/2025     03:00:00        COMPLETED     (null)          NaN  ...
# 2           NaN       (null)        COMPLETED     (null)          NaN  ...
# 3    05/22/2025     14:45:00        COMPLETED     (null)          NaN  ...
# 4    07/05/2025     18:31:00        COMPLETED     (null)          NaN  ...
# 5    09/03/2025     22:16:00        COMPLETED     (null)          NaN  ...
# 6           NaN       (null)        COMPLETED     (null)          NaN  ...
# 7           NaN       (null)        COMPLETED     (null)          NaN  ...
# 8    09/17/2025     18:10:00        COMPLETED     (null)          NaN  ...
# 9    04/03/2025     16:16:00        COMPLETED     (null)          NaN  ...
# 10   09/16/2025     16:05:00        COMPLETED     (null)          NaN  ...
# 11   04/05/2025     05:00:00        COMPLETED     (null)          NaN  ...
# 12   07/09/2025     23:40:00        COMPLETED     (null)          NaN  ...
# 13   08/09/2025     08:50:00        ATTEMPTED     (null)          NaN  ...
# 14   07/19/2025     17:50:00        COMPLETED     (null)          NaN  ...
# 15   08/22/2025     15:18:00        COMPLETED     (null)          NaN  ...
# 16   01/23/2025     16:00:00        COMPLETED     (null)          NaN  ...
# 17   01/26/2025     02:00:00        COMPLETED     (null)          NaN  ...
# 18   12/13/2024     12:30:00        COMPLETED     (null)          NaN  ...
# 19   07/03/2025     08:30:00        COMPLETED     (null)          NaN  ...
#
#     TRANSIT_DISTRICT VIC_AGE_GROUP                  VIC_RACE VIC_SEX  \
# 0                NaN         25-44                     WHITE       M
# 1                NaN         18-24                     WHITE       F
# 2                NaN         25-44                     BLACK       F
# 3                NaN       UNKNOWN                   UNKNOWN       M
# 4                NaN         18-24                     BLACK       F
# 5                NaN       UNKNOWN                   UNKNOWN       E
# 6                NaN         25-44                     BLACK       F
# 7                NaN         45-64            BLACK HISPANIC       F
# 8                NaN       UNKNOWN                   UNKNOWN       D
# 9                NaN         45-64  ASIAN / PACIFIC ISLANDER       M
# 10               NaN         25-44                     WHITE       M
# 11               NaN         25-44                     BLACK       F
# 12               NaN         45-64                     WHITE       F
# 13               NaN         45-64                     WHITE       F
# 14               NaN         25-44            BLACK HISPANIC       M
# 15               NaN       UNKNOWN                   UNKNOWN       D
# 16               NaN       UNKNOWN                   UNKNOWN       E
# 17               NaN           <18            WHITE HISPANIC       F
# 18               NaN           65+                     WHITE       M
# 19               NaN         25-44                     WHITE       F
#
#    X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0      988886     207857  40.737203 -73.983273
# 1     1005319     190473  40.689464 -73.924029
# 2     1026480     262584  40.887314 -73.847272
# 3           0          0   0.000000   0.000000
# 4           0          0   0.000000   0.000000
# 5           0          0   0.000000   0.000000
# 6           0          0   0.000000   0.000000
# 7           0          0   0.000000   0.000000
# 8      935629     167479  40.626245 -74.175157
# 9      950248     170326  40.634128 -74.122504
# 10     920609     124429  40.507984 -74.228859
# 11     924076     135348  40.537979 -74.216488
# 12     914868     126135  40.512625 -74.249522
# 13     954827     148519  40.574286 -74.105914
# 14     942001     169511  40.631844 -74.152213
# 15     942827     166373  40.623246 -74.149218
# 16     947021     172200  40.639258 -74.134141
# 17     942822     166353  40.623188 -74.149238
# 18     952887     146000  40.567366 -74.112885
# 19     935947     136273  40.540590 -74.173786
#
#                                   Lat_Lon  \
# 0   (40.7372030985741, -73.9832725981497)
# 1   (40.6894642952604, -73.9240290899499)
# 2   (40.8873136344706, -73.8472717577564)
# 3                              (0.0, 0.0)
# 4                              (0.0, 0.0)
# 5                              (0.0, 0.0)
# 6                              (0.0, 0.0)
# 7                              (0.0, 0.0)
# 8                 (40.626245, -74.175157)
# 9                 (40.634128, -74.122504)
# 10                (40.507984, -74.228859)
# 11                (40.537979, -74.216488)
# 12                (40.512625, -74.249522)
# 13  (40.5742856881925, -74.1059144051212)
# 14            (40.63184429, -74.15221345)
# 15                (40.623246, -74.149218)
# 16                (40.639258, -74.134141)
# 17  (40.6231883776008, -74.1492376947323)
# 18                (40.567366, -74.112885)
# 19                 (40.54059, -74.173786)
#
#                       New Georeferenced Column
# 0   POINT (-73.9832725981497 40.7372030985741)
# 1   POINT (-73.9240290899499 40.6894642952604)
# 2   POINT (-73.8472717577564 40.8873136344706)
# 3                                  POINT (0 0)
# 4                                  POINT (0 0)
# 5                                  POINT (0 0)
# 6                                  POINT (0 0)
# 7                                  POINT (0 0)
# 8                 POINT (-74.175157 40.626245)
# 9                 POINT (-74.122504 40.634128)
# 10                POINT (-74.228859 40.507984)
# 11                POINT (-74.216488 40.537979)
# 12                POINT (-74.249522 40.512625)
# 13  POINT (-74.1059144051212 40.5742856881925)
# 14            POINT (-74.15221345 40.63184429)
# 15                POINT (-74.149218 40.623246)
# 16                POINT (-74.134141 40.639258)
# 17  POINT (-74.1492376947323 40.6231883776008)
# 18                POINT (-74.112885 40.567366)
# 19                 POINT (-74.173786 40.54059)
#
# [20 rows x 36 columns]

# %%
print(complaints.isnull().sum())
# Out:
# CMPLNT_NUM                       0
# ADDR_PCT_CD                      0
# BORO_NM                          0
# CMPLNT_FR_DT                     0
# CMPLNT_FR_TM                     0
# CMPLNT_TO_DT                 20328
# CMPLNT_TO_TM                     0
# CRM_ATPT_CPTD_CD                 0
# HADEVELOPT                       0
# HOUSING_PSA                 411370
# JURISDICTION_CODE                0
# JURIS_DESC                       0
# KY_CD                            0
# LAW_CAT_CD                       0
# LOC_OF_OCCUR_DESC                0
# OFNS_DESC                        0
# PARKS_NM                         0
# PATROL_BORO                      0
# PD_CD                          243
# PD_DESC                          0
# PREM_TYP_DESC                    0
# RPT_DT                           0
# STATION_NAME                     0
# SUSP_AGE_GROUP                   0
# SUSP_RACE                        0
# SUSP_SEX                         0
# TRANSIT_DISTRICT            412298
# VIC_AGE_GROUP                    0
# VIC_RACE                         0
# VIC_SEX                          0
# X_COORD_CD                       0
# Y_COORD_CD                       0
# Latitude                         0
# Longitude                        0
# Lat_Lon                          0
# New Georeferenced Column         0
# dtype: int64

# %%
print('Columns:', complaints.columns)
# Out:
# Columns: Index(['CMPLNT_NUM', 'ADDR_PCT_CD', 'BORO_NM', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
#        'CMPLNT_TO_DT', 'CMPLNT_TO_TM', 'CRM_ATPT_CPTD_CD', 'HADEVELOPT',
#        'HOUSING_PSA', 'JURISDICTION_CODE', 'JURIS_DESC', 'KY_CD', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PARKS_NM', 'PATROL_BORO', 'PD_CD',
#        'PD_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'STATION_NAME', 'SUSP_AGE_GROUP',
#        'SUSP_RACE', 'SUSP_SEX', 'TRANSIT_DISTRICT', 'VIC_AGE_GROUP',
#        'VIC_RACE', 'VIC_SEX', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'Lat_Lon', 'New Georeferenced Column'],
#       dtype='object')

# %%
num_id_dupes = complaints.duplicated(subset=['CMPLNT_NUM']).sum()
print('Number of duplicate CMPLNT_NUM:', num_id_dupes)
print(complaints[complaints.duplicated(subset=['CMPLNT_NUM'])].head())
# Out:
# Number of duplicate CMPLNT_NUM: 0
# Empty DataFrame
# Columns: [CMPLNT_NUM, ADDR_PCT_CD, BORO_NM, CMPLNT_FR_DT, CMPLNT_FR_TM, CMPLNT_TO_DT, CMPLNT_TO_TM, CRM_ATPT_CPTD_CD, HADEVELOPT, HOUSING_PSA, JURISDICTION_CODE, JURIS_DESC, KY_CD, LAW_CAT_CD, LOC_OF_OCCUR_DESC, OFNS_DESC, PARKS_NM, PATROL_BORO, PD_CD, PD_DESC, PREM_TYP_DESC, RPT_DT, STATION_NAME, SUSP_AGE_GROUP, SUSP_RACE, SUSP_SEX, TRANSIT_DISTRICT, VIC_AGE_GROUP, VIC_RACE, VIC_SEX, X_COORD_CD, Y_COORD_CD, Latitude, Longitude, Lat_Lon, New Georeferenced Column]
# Index: []
#
# [0 rows x 36 columns]

# %%
columns_to_drop = [
    'SUSP_AGE_GROUP', 'SUSP_RACE', 'SUSP_SEX',
    'VIC_AGE_GROUP', 'VIC_RACE', 'VIC_SEX',
    'PARKS_NM', 'HADEVELOPT', 'HOUSING_PSA',
    'Lat_Lon', 'CMPLNT_FR_DT', 'CMPLNT_FR_TM',
    'TRANSIT_DISTRICT', 'STATION_NAME',
    'X_COORD_CD', 'Y_COORD_CD',
    'KY_CD', 'PD_CD', 'PD_DESC',
    'CMPLNT_TO_TM', 'CMPLNT_NUM', 'ADDR_PCT_CD'
    'JURISDICTION_CODE', 'ADDR_PCT_CD', 'JURISDICTION_CODE', 'PATROL_BORO',
    'CMPLNT_TO_DT'
]

complaints = complaints.drop(columns=columns_to_drop, errors='ignore')

print('Columns after dropping:', complaints.columns)
print('Shape after step:', complaints.shape)
# Out:
# Columns after dropping: Index(['BORO_NM', 'CRM_ATPT_CPTD_CD', 'JURIS_DESC', 'LAW_CAT_CD',
#        'LOC_OF_OCCUR_DESC', 'OFNS_DESC', 'PREM_TYP_DESC', 'RPT_DT', 'Latitude',
#        'Longitude', 'New Georeferenced Column'],
#       dtype='object')
# Shape after step: (438556, 11)

# %%
print(complaints.head(20))
# Out:
#           BORO_NM CRM_ATPT_CPTD_CD        JURIS_DESC   LAW_CAT_CD  \
# 0       MANHATTAN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 1        BROOKLYN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 2           BRONX        COMPLETED  N.Y. POLICE DEPT       FELONY
# 3       MANHATTAN        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 4       MANHATTAN        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 5           BRONX        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 6          QUEENS        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 7       MANHATTAN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 8   STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 9   STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT    VIOLATION
# 10  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 11  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 12  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 13  STATEN ISLAND        ATTEMPTED  N.Y. POLICE DEPT  MISDEMEANOR
# 14  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 15  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 16  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 17  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 18  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 19  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
#
#    LOC_OF_OCCUR_DESC                       OFNS_DESC           PREM_TYP_DESC  \
# 0             INSIDE                            RAPE                HOSPITAL
# 1           FRONT OF                            RAPE                  STREET
# 2             INSIDE                            RAPE         RESIDENCE-HOUSE
# 3             (null)    ASSAULT 3 & RELATED OFFENSES                  STREET
# 4           FRONT OF    ASSAULT 3 & RELATED OFFENSES                  STREET
# 5             (null)                 DANGEROUS DRUGS                  STREET
# 6             (null)                   PETIT LARCENY                  STREET
# 7             (null)                   GRAND LARCENY                  STREET
# 8             INSIDE                   PETIT LARCENY        DEPARTMENT STORE
# 9             INSIDE                   HARRASSMENT 2        RESTAURANT/DINER
# 10          FRONT OF    ASSAULT 3 & RELATED OFFENSES         RESIDENCE-HOUSE
# 11            INSIDE  CRIMINAL MISCHIEF & RELATED OF         RESIDENCE-HOUSE
# 12            INSIDE                  FELONY ASSAULT         RESIDENCE-HOUSE
# 13            INSIDE                      SEX CRIMES         RESIDENCE-HOUSE
# 14            (null)    ASSAULT 3 & RELATED OFFENSES                  STREET
# 15            INSIDE                   PETIT LARCENY             CHAIN STORE
# 16            INSIDE                 DANGEROUS DRUGS  RESIDENCE - APT. HOUSE
# 17            INSIDE                            RAPE  RESIDENCE - APT. HOUSE
# 18            INSIDE                   GRAND LARCENY                    BANK
# 19          FRONT OF  CRIMINAL MISCHIEF & RELATED OF         RESIDENCE-HOUSE
#
#         RPT_DT   Latitude  Longitude  \
# 0   03/20/2025  40.737203 -73.983273
# 1   01/02/2025  40.689464 -73.924029
# 2   05/30/2025  40.887314 -73.847272
# 3   05/22/2025   0.000000   0.000000
# 4   07/05/2025   0.000000   0.000000
# 5   09/03/2025   0.000000   0.000000
# 6   04/01/2025   0.000000   0.000000
# 7   08/12/2025   0.000000   0.000000
# 8   09/20/2025  40.626245 -74.175157
# 9   04/03/2025  40.634128 -74.122504
# 10  09/17/2025  40.507984 -74.228859
# 11  04/05/2025  40.537979 -74.216488
# 12  07/10/2025  40.512625 -74.249522
# 13  08/09/2025  40.574286 -74.105914
# 14  07/19/2025  40.631844 -74.152213
# 15  08/22/2025  40.623246 -74.149218
# 16  03/07/2025  40.639258 -74.134141
# 17  01/29/2025  40.623188 -74.149238
# 18  01/16/2025  40.567366 -74.112885
# 19  07/03/2025  40.540590 -74.173786
#
#                       New Georeferenced Column
# 0   POINT (-73.9832725981497 40.7372030985741)
# 1   POINT (-73.9240290899499 40.6894642952604)
# 2   POINT (-73.8472717577564 40.8873136344706)
# 3                                  POINT (0 0)
# 4                                  POINT (0 0)
# 5                                  POINT (0 0)
# 6                                  POINT (0 0)
# 7                                  POINT (0 0)
# 8                 POINT (-74.175157 40.626245)
# 9                 POINT (-74.122504 40.634128)
# 10                POINT (-74.228859 40.507984)
# 11                POINT (-74.216488 40.537979)
# 12                POINT (-74.249522 40.512625)
# 13  POINT (-74.1059144051212 40.5742856881925)
# 14            POINT (-74.15221345 40.63184429)
# 15                POINT (-74.149218 40.623246)
# 16                POINT (-74.134141 40.639258)
# 17  POINT (-74.1492376947323 40.6231883776008)
# 18                POINT (-74.112885 40.567366)
# 19                 POINT (-74.173786 40.54059)

# %%
num_exact_dupes = complaints.duplicated().sum()
print('Number of fully duplicated rows:', num_exact_dupes)
# Out:
# Number of fully duplicated rows: 24181

# %%
complaints = complaints.drop_duplicates()
print('Shape after step:', complaints.shape)
# Out:
# Shape after step: (414375, 11)

# %%
print(complaints.isnull().sum())
# Out:
# BORO_NM                     0
# CRM_ATPT_CPTD_CD            0
# JURIS_DESC                  0
# LAW_CAT_CD                  0
# LOC_OF_OCCUR_DESC           0
# OFNS_DESC                   0
# PREM_TYP_DESC               0
# RPT_DT                      0
# Latitude                    0
# Longitude                   0
# New Georeferenced Column    0
# dtype: int64

# %%
print(complaints['BORO_NM'].value_counts())
print(complaints.head(30))
# Out:
# BORO_NM
# BROOKLYN         116502
# MANHATTAN         95981
# BRONX             94069
# QUEENS            88853
# STATEN ISLAND     18037
# (null)              933
# Name: count, dtype: int64
#           BORO_NM CRM_ATPT_CPTD_CD        JURIS_DESC   LAW_CAT_CD  \
# 0       MANHATTAN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 1        BROOKLYN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 2           BRONX        COMPLETED  N.Y. POLICE DEPT       FELONY
# 3       MANHATTAN        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 4       MANHATTAN        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 5           BRONX        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 6          QUEENS        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 7       MANHATTAN        COMPLETED  N.Y. POLICE DEPT       FELONY
# 8   STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 9   STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT    VIOLATION
# 10  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 11  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 12  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 13  STATEN ISLAND        ATTEMPTED  N.Y. POLICE DEPT  MISDEMEANOR
# 14  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 15  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 16  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 17  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 18  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 19  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 20  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 21  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT    VIOLATION
# 22  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT    VIOLATION
# 23  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 24  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 25  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT    VIOLATION
# 26  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 27  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
# 28  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT       FELONY
# 29  STATEN ISLAND        COMPLETED  N.Y. POLICE DEPT  MISDEMEANOR
#
#    LOC_OF_OCCUR_DESC                       OFNS_DESC           PREM_TYP_DESC  \
# 0             INSIDE                            RAPE                HOSPITAL
# 1           FRONT OF                            RAPE                  STREET
# 2             INSIDE                            RAPE         RESIDENCE-HOUSE
# 3             (null)    ASSAULT 3 & RELATED OFFENSES                  STREET
# 4           FRONT OF    ASSAULT 3 & RELATED OFFENSES                  STREET
# 5             (null)                 DANGEROUS DRUGS                  STREET
# 6             (null)                   PETIT LARCENY                  STREET
# 7             (null)                   GRAND LARCENY                  STREET
# 8             INSIDE                   PETIT LARCENY        DEPARTMENT STORE
# 9             INSIDE                   HARRASSMENT 2        RESTAURANT/DINER
# 10          FRONT OF    ASSAULT 3 & RELATED OFFENSES         RESIDENCE-HOUSE
# 11            INSIDE  CRIMINAL MISCHIEF & RELATED OF         RESIDENCE-HOUSE
# 12            INSIDE                  FELONY ASSAULT         RESIDENCE-HOUSE
# 13            INSIDE                      SEX CRIMES         RESIDENCE-HOUSE
# 14            (null)    ASSAULT 3 & RELATED OFFENSES                  STREET
# 15            INSIDE                   PETIT LARCENY             CHAIN STORE
# 16            INSIDE                 DANGEROUS DRUGS  RESIDENCE - APT. HOUSE
# 17            INSIDE                            RAPE  RESIDENCE - APT. HOUSE
# 18            INSIDE                   GRAND LARCENY                    BANK
# 19          FRONT OF  CRIMINAL MISCHIEF & RELATED OF         RESIDENCE-HOUSE
# 20            INSIDE    ASSAULT 3 & RELATED OFFENSES         RESIDENCE-HOUSE
# 21            INSIDE         MISCELLANEOUS PENAL LAW         RESIDENCE-HOUSE
# 22            INSIDE                   HARRASSMENT 2         RESIDENCE-HOUSE
# 23            INSIDE    ASSAULT 3 & RELATED OFFENSES         RESIDENCE-HOUSE
# 24            INSIDE    ASSAULT 3 & RELATED OFFENSES         RESIDENCE-HOUSE
# 25            INSIDE                   HARRASSMENT 2         RESIDENCE-HOUSE
# 26            INSIDE                        BURGLARY        RESTAURANT/DINER
# 27            INSIDE                      SEX CRIMES         RESIDENCE-HOUSE
# 28            INSIDE                  FELONY ASSAULT         RESIDENCE-HOUSE
# 29            INSIDE                   PETIT LARCENY          GROCERY/BODEGA
#
#         RPT_DT   Latitude  Longitude  \
# 0   03/20/2025  40.737203 -73.983273
# 1   01/02/2025  40.689464 -73.924029
# 2   05/30/2025  40.887314 -73.847272
# 3   05/22/2025   0.000000   0.000000
# 4   07/05/2025   0.000000   0.000000
# 5   09/03/2025   0.000000   0.000000
# 6   04/01/2025   0.000000   0.000000
# 7   08/12/2025   0.000000   0.000000
# 8   09/20/2025  40.626245 -74.175157
# 9   04/03/2025  40.634128 -74.122504
# 10  09/17/2025  40.507984 -74.228859
# 11  04/05/2025  40.537979 -74.216488
# 12  07/10/2025  40.512625 -74.249522
# 13  08/09/2025  40.574286 -74.105914
# 14  07/19/2025  40.631844 -74.152213
# 15  08/22/2025  40.623246 -74.149218
# 16  03/07/2025  40.639258 -74.134141
# 17  01/29/2025  40.623188 -74.149238
# 18  01/16/2025  40.567366 -74.112885
# 19  07/03/2025  40.540590 -74.173786
# 20  04/13/2025  40.614100 -74.129081
# 21  05/20/2025  40.640099 -74.168138
# 22  06/26/2025  40.578879 -74.123083
# 23  04/26/2025  40.587848 -74.151517
# 24  05/05/2025  40.551148 -74.198795
# 25  08/26/2025  40.590363 -74.190370
# 26  06/27/2025  40.537191 -74.150609
# 27  03/25/2025  40.623188 -74.149238
# 28  06/29/2025  40.547249 -74.210191
# 29  04/29/2025  40.567366 -74.112885
#
#                       New Georeferenced Column
# 0   POINT (-73.9832725981497 40.7372030985741)
# 1   POINT (-73.9240290899499 40.6894642952604)
# 2   POINT (-73.8472717577564 40.8873136344706)
# 3                                  POINT (0 0)
# 4                                  POINT (0 0)
# 5                                  POINT (0 0)
# 6                                  POINT (0 0)
# 7                                  POINT (0 0)
# 8                 POINT (-74.175157 40.626245)
# 9                 POINT (-74.122504 40.634128)
# 10                POINT (-74.228859 40.507984)
# 11                POINT (-74.216488 40.537979)
# 12                POINT (-74.249522 40.512625)
# 13  POINT (-74.1059144051212 40.5742856881925)
# 14            POINT (-74.15221345 40.63184429)
# 15                POINT (-74.149218 40.623246)
# 16                POINT (-74.134141 40.639258)
# 17  POINT (-74.1492376947323 40.6231883776008)
# 18                POINT (-74.112885 40.567366)
# 19                 POINT (-74.173786 40.54059)
# 20                  POINT (-74.129081 40.6141)
# 21                POINT (-74.168138 40.640099)
# 22                POINT (-74.123083 40.578879)
# 23                POINT (-74.151517 40.587848)
# 24                POINT (-74.198795 40.551148)
# 25                 POINT (-74.19037 40.590363)
# 26                POINT (-74.150609 40.537191)
# 27  POINT (-74.1492376947323 40.6231883776008)
# 28                POINT (-74.210191 40.547249)
# 29                POINT (-74.112885 40.567366)

# %%
print('Cleaned complaints shape:', complaints.shape)
# Out:
# Cleaned complaints shape: (414375, 11)

# %%
complaints.to_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Processed Data/complaints_processed.csv')
print("File saved")
