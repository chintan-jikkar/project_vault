# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
property_sales = pd.read_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Cleaned_NYC_Property_Sales.csv')
crime_data = pd.read_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Cleaned_NYPD_Complaints.csv')
air_quality = pd.read_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Cleaned_NYC_Air_Quality.csv')
master_data = pd.read_csv('/Users/chintanjikkar/Desktop/PACE/Fall 25/Visual Analytics/Team Project/Final_Merged_Data.csv')

# %%
print("Shape of Property Sales Data:", property_sales.shape)
print("Shape of Crime Data:", crime_data.shape)
print("Shape of Air Quality Data:", air_quality.shape)
print("Shape of Master Data:", master_data.shape)
# Out:
# Shape of Property Sales Data: (1294143, 29)
# Shape of Crime Data: (4880471, 12)
# Shape of Air Quality Data: (19426, 9)
# Shape of Master Data: (0, 50)
