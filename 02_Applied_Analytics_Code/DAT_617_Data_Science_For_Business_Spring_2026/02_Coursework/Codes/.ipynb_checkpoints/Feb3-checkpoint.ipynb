# %% [markdown]
# BASIC ARITHMETIC

# %%
123 * 456 + 789
# Out:
# 56877

# %%
123 * (456 + 789)
# Out:
# 153135

# %% [markdown]
# Object/Variable Assignment

# %%
a = 45
b = 34

# %%
a * b
# Out:
# 1530

# %%
#Doing the assignment the other way 5 = x doesnt work as python reads from right to left

# %%
cool_class = 4

# %%
cool_class * 4
# Out:
# 16

# %%
CoolClass = 7
CoolClass *3
# Out:
# 21

# %%
cool_class * CoolClass
# Out:
# 28

# %%
pneumonoultramicroscopicsilicovolcanoconiosis = 69

# %%
#Example of using tab to fastfill things while coding
pneumonoultramicroscopicsilicovolcanoconiosis
# Out:
# 69

# %%
#Also you can do this
smoll = pneumonoultramicroscopicsilicovolcanoconiosis
smoll
# Out:
# 69

# %%
type(cool_class)
# Out:
# int

# %%
#Converting one type to another is called coersing

# %%
str(smoll)
# Out:
# '69'

# %%
bool(0)
# Out:
# False

# %%
bool(smoll)
# Out:
# True

# %%
bool(2101)
# Out:
# True

# %%
#bool False only for 0 else True

# %%
5 == 5
# Out:
# True

# %%
5 !=5
# Out:
# False

# %%
#Objects have methods and attributes

# %% [markdown]
# Method is a function applied to an object
# Attribute is a characteristic of the object

# %%
my_name = 'chintan'

# %%
my_name.capitalize()
# Out:
# 'Chintan'

# %%
#Anything inside a [] square bracket is a list

# %%
[1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['a', 'b', 'c', 'd']
# Out:
# ['a', 'b', 'c', 'd']

# %%
['a', 2, 'c', 4, 'e']
# Out:
# ['a', 2, 'c', 4, 'e']

# %%
#the python list function is a garbage bag it will take anything you give it irrespective of the type tho it is not recommended as it makes your work cumbersone

# %%
dict = {'id': 1, 
        'name': 'Chintan Jikkar', 
        'income': 1000000000000}

# %%
dict
# Out:
# {'id': 1, 'name': 'Chintan Jikkar', 'income': 1000000000000}

# %%
dict = {'id': [1, 2], 
        'name': ['Chintan Jikkar', 'Shivali Shetty'],
        'income': [1000000000000, 1100000000000]}

# %%
dict
# Out:
# {'id': [1, 2],
#  'name': ['Chintan Jikkar', 'Shivali Shetty'],
#  'income': [1000000000000, 1100000000000]}

# %% [markdown]
# Numpy

# %%
import numpy as np

# %%
np.array([1, 2, 3, 4, 'Cj'])
# Out:
# array(['1', '2', '3', '4', 'Cj'], dtype='<U21')

# %%
lst = [1, 2, 3, 4, 'Cj']
np.array(lst)
# Out:
# array(['1', '2', '3', '4', 'Cj'], dtype='<U21')

# %%
np.array(lst).dtype
# Out:
# dtype('<U21')

# %%
#dtype is the attribute here

# %%
lst2 = [1, 2, 3, 4,]
arr = np.array(lst2)
arr.dtype
# Out:
# dtype('int64')

# %%
lst3 = [1, 2, 3, 4]
arr = np.array(lst3, dtype= np.int16)
arr.dtype
# Out:
# dtype('int16')

# %%
#this was an example of using a param that is inbuilt in the function

# %%
np.array(lst3).shape
# Out:
# (4,)

# %%
np.array(lst3).reshape(2,2)
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
lst4 = [1, 2, 3, 4, 5, 6]
new_arr = np.array(lst4).reshape(3,2)
print(new_arr.shape)
print(new_arr)
print('XOXOXOXO')
new_arr2 = np.array(lst4).reshape(2,3)
print(new_arr2.shape)
print(new_arr2)
# Out:
# (3, 2)
# [[1 2]
#  [3 4]
#  [5 6]]
# XOXOXOXO
# (2, 3)
# [[1 2 3]
#  [4 5 6]]

# %%
#Most prog lang count from 0 so if we are counting somethins this is the output we get

# %%
new_arr2[1,1]
# Out:
# np.int64(5)

# %%
#So 1 = 0,0 and 6 = 1,2

# %%
new_arr3 = np.array(lst4).reshape(2,3)
new_arr3 + 2
# Out:
# array([[3, 4, 5],
#        [6, 7, 8]])

# %%
#but if you use this with lists

# %%
[1, 2, 3] * 2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
np.random.randint(low= 0, high= 9, size= 10)
# Out:
# array([4, 7, 8, 3, 5, 2, 6, 2, 8, 4])

# %%
np.random.seed(2101)
np.random.randint(low= 0, high= 9, size= 10)
# Out:
# array([7, 1, 4, 7, 8, 0, 1, 7, 8, 5])

# %%
np.random.seed(617)
np.random.randint(low= 0, high= 9, size= 1_000_000).reshape(1000,1000)
# Out:
# array([[1, 2, 8, ..., 1, 4, 7],
#        [3, 8, 7, ..., 5, 5, 4],
#        [4, 0, 3, ..., 6, 6, 7],
#        ...,
#        [4, 4, 1, ..., 2, 1, 6],
#        [7, 1, 7, ..., 8, 5, 1],
#        [2, 5, 6, ..., 0, 3, 3]], shape=(1000, 1000))

# %%
np.array([1.11,2.22,3.33,4.44,5.55], dtype=np.int8)
# Out:
# array([1, 2, 3, 4, 5], dtype=int8)

# %%
np.array([1,2,3]).astype('float32')
# Out:
# array([1., 2., 3.], dtype=float32)

# %%
np.array([1031,True, 617])
# Out:
# array([1031,    1,  617])

# %%
np.array([1,2,3,4,5])> 3
# Out:
# array([False, False, False,  True,  True])

# %%
array1 = np.array([[1,2,3,4],
                   [10,20,30,40]])
array2 = np.array([1,2]).reshape(2,1)
print(array1 + array2)
# Out:
# [[ 2  3  4  5]
#  [12 22 32 42]]

# %%
#if your arrays are of different shapes it will try to work something out for you if possible else there might be a need to reshape it

# %%
# !pip install Pillow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 3.3 MB/s  0:00:01m 3.3 MB/s eta 0:00:01
# ...

# %%
from PIL import Image

# %%
from IPython.display import display
og = Image.open('/Users/chintanjikkar/Desktop/PACE/Spring 26/Data Science for Business/Data/image.jpg')
display(og)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x414>

# %%
og_array = np.array(og)
og_array
# Out:
# array([[[ 56,  56,  56],
#         [ 58,  58,  58],
#         [ 59,  59,  59],
#         ...,
#         [ 32,  33,  28],
#         [ 32,  33,  28],
#         [ 32,  33,  28]],
#
#        [[ 53,  53,  53],
#         [ 55,  55,  55],
#         [ 57,  57,  57],
#         ...,
#         [ 32,  33,  28],
#         [ 32,  33,  28],
#         [ 32,  33,  28]],
#
#        [[ 54,  54,  54],
#         [ 55,  55,  55],
#         [ 56,  56,  56],
#         ...,
#         [ 31,  32,  27],
#         [ 31,  32,  27],
#         [ 31,  32,  27]],
#
#        ...,
#
#        [[ 44,  44,  46],
#         [ 55,  55,  57],
#         [ 52,  52,  54],
#         ...,
#         [230, 235, 229],
#         [232, 234, 229],
#         [232, 234, 229]],
#
#        [[ 39,  39,  41],
#         [ 64,  64,  66],
#         [ 62,  62,  64],
#         ...,
#         [232, 234, 229],
#         [232, 234, 229],
#         [232, 234, 229]],
#
#        [[ 67,  67,  69],
#         [ 75,  75,  77],
#         [ 45,  45,  47],
# ...

# %%
import pandas as pd

# %%
lst = [1,2,3]
pd.Series(lst)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.DataFrame(np.random.randint(0,9,100).reshape(25,4))
# Out:
#     0  1  2  3
# 0   4  1  8  0
# 1   3  0  0  6
# 2   6  1  0  1
# 3   4  3  5  4
# 4   6  5  3  6
# 5   4  5  6  8
# 6   5  0  1  0
# 7   0  2  7  6
# 8   2  2  8  8
# 9   4  1  3  0
# 10  5  0  2  5
# 11  7  2  6  3
# 12  5  0  1  3
# 13  7  7  8  6
# 14  6  3  7  3
# 15  2  6  6  5
# 16  1  5  0  2
# 17  1  2  3  6
# 18  7  7  7  7
# 19  6  5  8  1
# 20  1  3  1  1
# 21  8  3  4  4
# 22  3  6  0  6
# 23  3  5  5  5
# 24  0  1  5  0

# %%
pd.DataFrame(dict)
# Out:
#    id            name         income
# 0   1  Chintan Jikkar  1000000000000
# 1   2  Shivali Shetty  1100000000000

# %%
#In deep learning applications we will use Numpy arrays exclusively

# %%
lst = [4,8,12,16]
dat = pd.Series(lst)
dat
# Out:
# 0     4
# 1     8
# 2    12
# 3    16
# dtype: int64

# %%
dat[0:1]
# Out:
# 0    4
# dtype: int64

# %%
dat[0:2]
# Out:
# 0    4
# 1    8
# dtype: int64

# %%
dat[:3]
# Out:
# 0     4
# 1     8
# 2    12
# dtype: int64

# %%
dat[1:3]
# Out:
# 1     8
# 2    12
# dtype: int64

# %%
txt = 'this class'
len(txt)
# Out:
# 10

# %%
txt.upper()
# Out:
# 'THIS CLASS'

# %%
txt.capitalize()
# Out:
# 'This class'

# %%
coffee_expense = pd.Series([4,6,4,4,7,0,0])
coffee_expense.mode()
# Out:
# 0    4
# dtype: int64

# %%
coffee_expense.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# DataFrame

# %%
dict_raw = {'names':['Nikhil','Rohan','Sharmila','Vishal'],
            'gender':['Male','Male','Female','Male'],
            'favorite_fruit': [None, 'Pomegranate','Mango','Pomegranate'],
            'sleep_hours': [8,7,6,6]}
data = pd.DataFrame(dict_raw)
data
# Out:
#       names  gender favorite_fruit  sleep_hours
# 0    Nikhil    Male           None            8
# 1     Rohan    Male    Pomegranate            7
# 2  Sharmila  Female          Mango            6
# 3    Vishal    Male    Pomegranate            6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   names           4 non-null      object
#  1   gender          4 non-null      object
#  2   favorite_fruit  3 non-null      object
#  3   sleep_hours     4 non-null      int64
# dtypes: int64(1), object(3)
# memory usage: 260.0+ bytes

# %%
data.describe
# Out:
# <bound method NDFrame.describe of       names  gender favorite_fruit  sleep_hours
# 0    Nikhil    Male           None            8
# 1     Rohan    Male    Pomegranate            7
# 2  Sharmila  Female          Mango            6
# 3    Vishal    Male    Pomegranate            6>

# %%
#BUT
data.describe()
# Out:
#        sleep_hours
# count     4.000000
# mean      6.750000
# std       0.957427
# min       6.000000
# 25%       6.000000
# 50%       6.500000
# 75%       7.250000
# max       8.000000
