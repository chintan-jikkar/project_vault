# %% [markdown]
# # In-Class Exercise: Data Parsing
#
# This exercise uses a messy movie dataset (`movies_messy.csv`). Your task is to clean and explore the dataset.

# %% [markdown]
# ## 1) Load the Data
# A. Import pandas as pd.
# B. Read `movies_messy.csv` into a DataFrame called `movies`.
# C. Display the first 5 rows.

# %%
# A. Import pandas


# B. Read CSV


# C. Head

# %% [markdown]
# ## 2) Splitting Columns
# A. Split the column `genre_info` into two columns: `genre` and `language`.
# B. Strip any extra spaces.

# %%
# A. Split genre_info


# B. Strip spaces

# %% [markdown]
# ## 3) Handling Missing & Dates
# A. Replace 'unknown' in `release_date` with None.
# B. Convert `release_date` into proper datetime format.

# %%
# A. Replace 'unknown'


# B. To datetime

# %% [markdown]
# ## 4) Cleaning Numeric Columns
# A. Clean `budget_usd` by removing symbols and converting to float.
# B. Clean `revenue_million` by removing 'M', handling 'N/A', and converting to float.

# %%
# A. Clean budget_usd


# B. Clean revenue_million

# %% [markdown]
# ## 5) Exploring the Cleaned Data
# A. Print `.info()`.
# B. Compute the average budget.
# C. Compute the average revenue by genre.

# %%
# A. info()


# B. Average budget


# C. Group by genre
