# %% [markdown]
# # In-Class Exercise: Restructuring Data
#
# This notebook contains practice exercises for merging, melting, and pivoting using Pandas.
#
# ### Datasets Provided
# 1. **customers_toy.csv** – customer IDs, names, and emails.
# 2. **orders_toy.csv** – order transactions with customer IDs, amounts, and dates.
# 3. **sales_toy.csv** – wide-format quarterly sales data for two products across cities.
# 4. **survey_toy.csv** – survey responses in wide format.
#
# Fill in the code cells with your answers.

# %% [markdown]
# ## 1) Load Customer & Order Data
# A. Load `customers_toy.csv` and `orders_toy.csv` into DataFrames.
# B. Display the first 5 rows of each.

# %%
# A. Load customers and orders


# B. Display heads

# %% [markdown]
# ## 2) Inner Join
# Perform an **inner join** between customers and orders on `customer_id`.

# %%
# Inner join

# %% [markdown]
# ## 3) Left Join
# Perform a **left join** to keep all customers, even if they don’t have orders.

# %%
# Left join

# %% [markdown]
# ## 4) Right Join
# Perform a **right join** to keep all orders, even if the customer is missing.

# %%
# Right join

# %% [markdown]
# ## 5) Outer Join
# Perform a **full outer join** of customers and orders.

# %%
# Outer join

# %% [markdown]
# ## 6) Wide to Long (Sales Data)
# Load `sales_toy.csv`. Convert wide format into long format with columns: `City`, `Product`, `Quarter`, `Sales`.

# %%
# Wide to long with melt

# %% [markdown]
# ## 7) Long to Wide (Sales Data)
# Take the long-format sales DataFrame and pivot it back to wide format.

# %%
# Long to wide with pivot

# %% [markdown]
# ## 8) Survey Data – Wide to Long
# Load `survey_toy.csv`. Use `pd.melt` to reshape into long format with columns: `id`, `item`, `response`.

# %%
# Survey wide to long

# %% [markdown]
# ## 9) Long to Wide (Survey Data)
# Take the melted survey DataFrame and pivot it back to wide format with `id` as index.

# %%
# Survey long to wide

# %% [markdown]
# ## 10) Reflection
# In 2–3 sentences, explain the difference between **melt** and **pivot** in Pandas. Why are these operations useful?

# %%
# Your explanation here
