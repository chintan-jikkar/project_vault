# %% [markdown]
# # In-Class Exercise: Feature Engineering
#
# We will practice feature engineering using the toy dataset `customers_toy_features.csv`.

# %% [markdown]
# ## 1) Load the Dataset
# Load `customers_toy_features.csv` into a DataFrame and display the first 5 rows.

# %%
# Load dataset

# %% [markdown]
# ## 2) Handling Missing Values
# A. Count missing values in each column.
# B. Fill missing ages with the mean.

# %%
# Count missing and fill ages

# %% [markdown]
# ## 3) Binning Continuous Variables
# Bin `age` into categories: '<25', '25-40', '41-60', '60+'.

# %%
# Bin ages

# %% [markdown]
# ## 4) One-Hot Encoding – Gender
# Encode the `gender` column using one-hot encoding.

# %%
# One-hot encode gender

# %% [markdown]
# ## 5) One-Hot Encoding – Marital Status
# Encode the `marital_status` column using `pd.get_dummies`, keeping all categories.

# %%
# One-hot encode marital_status

# %% [markdown]
# ## 6) Grouping Rare Categories
# If a marital status category has fewer than 2 counts, replace it with 'Other'.

# %%
# Group rare categories

# %% [markdown]
# ## 7) Ordered Categories
# Convert marital status into an ordered categorical variable: ['single','married','divorced','widowed','Other'].

# %%
# Ordered categorical marital_status

# %% [markdown]
# ## 8) Extracting Date Features
# From `signup_date`, extract year, month, and weekday.

# %%
# Extract year, month, weekday

# %% [markdown]
# ## 9) Days Since Signup
# Create a new feature `days_since_signup` = today - signup_date.

# %%
# Compute days since signup

# %% [markdown]
# ## 10) Polynomial and Interaction Features
# Create quadratic and interaction features for age and income.

# %%
# Construct interactions and polynomial terms

# %% [markdown]
# ## 11) Log Transform
# Apply a log transform to `income` to reduce skew.

# %%
# Log transform income

# %% [markdown]
# ## 12) Text Features – Contains Words
# From `feedback`, create binary features for 'good', 'bad', 'fast'.

# %%
# Extract text indicators

# %% [markdown]
# ## 13) Text Features – Length
# Create a new feature `feedback_length` = number of characters in feedback.

# %%
# Compute feedback length

# %% [markdown]
# ## 14) Feature Scaling
# Scale `income` and `purchases` using Min-Max scaling.

# %%
# MinMax scaling

# %% [markdown]
# ## 15) Feature Selection – Variance Threshold
# Use VarianceThreshold(threshold=0.01) to remove low-variance features.

# %%
# VarianceThreshold
