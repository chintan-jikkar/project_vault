# %% [markdown]
# #### This code will print out how awesome i am.

# %%
# This code will print how awesome I am.
print('I am amazing')
# Out:
# I am amazing

# %%
123 * 456 + 789
# Out:
# 56877

# %%
123 * 298734 + 283748798 - 83947900 * 374384796 / 22837493290-812937+89234983879032
123 * (456 + 789)
# Out:
# 153135

# %%
x=4
y=5
x+y
# Out:
# 9

# %%
a = a + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a = a + 1
#
# NameError: name 'a' is not defined

# %%
a = a + 1
a
# Out:
# 46

# %%
4 = x
# Out:
#   Cell In[6], line 1
#     4 = x
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a = 45
b = 34
a * b
# 45 = c # will generate an error
# Out:
# 1530

# %%
sin(45)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sin(45)
#
# NameError: name 'sin' is not defined

# %%
AgeNextYear = 55
# this is called giraffe case
age_next_year = 55
# this is the other way to do it

# %%
type("45")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(None)
# Out:
# NoneType

# %%
ice_cream = 'Häagen-Dazs'
ice_cream.encode('utf-8')
# Out:
# b'H\xc3\xa4agen-Dazs'

# %%
True + 1
# Out:
# 2

# %%
(True + 1) * False
# Out:
# 0

# %%
int(3.145689)
# Out:
# 3

# %%
len('it is gonna be time to wrap up soon...prof')
# Out:
# 42
